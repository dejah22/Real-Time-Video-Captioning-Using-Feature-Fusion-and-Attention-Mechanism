# %%
import os
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
print('mount success')
# Out:
# Mounted at /content/drive
# mount success

# %%
base_path = '/content/drive/Shareddrives/Final-Year-Project/github-data'
test_path = os.path.join(base_path, 'testing_data')
input_path = os.path.join(test_path, 'real-time-video')
split_path = os.path.join(test_path, 'split-video')
output_path = os.path.join(test_path, 'output_video')

# %%
import os
import sys
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.editor import VideoFileClip

# %%
def split_video(filename, segment_length, output_dir):
    clip = VideoFileClip(filename)
    duration = clip.duration
    print(duration)

    start_time = 0
    end_time = segment_length
    i = 1

    # Extract the filename without extension
    basename = os.path.basename(filename).split('.')[0]

    output_path = os.path.join(output_dir, basename)

    # Create output directory if it doesn't exist
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    while start_time < duration:
        output = os.path.join(output_path, f"{basename}_part{i}.mp4")
        ffmpeg_extract_subclip(filename, start_time, min(end_time, duration), targetname=output)
        start_time = end_time
        end_time += segment_length
        i += 1
    print(f'Video split into {i-1} parts.')

# %%
video_filename = "filename.mp4"

# %%
if __name__ == "__main__":
    video_input_path = os.path.join(input_path, video_filename)
    segment_length = 3
    video_output_path = split_path
    split_video(video_input_path, segment_length, video_output_path)
# Out:
# 12.12
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Video split into 5 parts.
